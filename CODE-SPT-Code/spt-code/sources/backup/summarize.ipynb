# %%
import csv

# data = [
#     {"Index": 1, "Method Name": "rot", "#Tokens": 45, "#Method Calls": 1},
#     {"Index": 2, "Method Name": "resumeSound", "#Tokens": 16, "#Method Calls": 4},
#     {"Index": 3, "Method Name": "putVertex", "#Tokens": 136, "#Method Calls": 0},
#     {"Index": 4, "Method Name": "derivative", "#Tokens": 68, "#Method Calls": 11},
#     {"Index": 5, "Method Name": "getNumPoints", "#Tokens": 5, "#Method Calls": 1},
#     {"Index": 6, "Method Name": "stopSourcesWithBuffer", "#Tokens": 31, "#Method Calls": 6},
#     {"Index": 7, "Method Name": "readClassDefinition", "#Tokens": 33, "#Method Calls": 4},
#     {"Index": 8, "Method Name": "draw", "#Tokens": 60, "#Method Calls": 5},
#     {"Index": 9, "Method Name": "set", "#Tokens": 14, "#Method Calls": 0},
#     {"Index": 10, "Method Name": "EncodeDirectBits", "#Tokens": 19, "#Method Calls": 1},
# ]

file_name = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
data = []

with open(file_name, mode='r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        data.append({
            "Index": int(row["Index"]),
            "Method Name": row["Method Name"].strip(),
            "#Tokens": int(row["#Tokens"]),
            "#Method Calls": int(row["#Method Calls"])
        })

for row in data:
    print(row)
    break
# Out:
# {'Index': 1, 'Method Name': 'createConfigurationPersister', '#Tokens': 41, '#Method Calls': 7}

# %%
file_name = 'input_ranges.csv'
ranges = []

with open(file_name, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        ranges.append((int(row[0]), int(row[1])))

print(ranges)

range_counts = []

for r in ranges:
    count = sum(1 for d in data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count))

with open('summarized_methods.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods","# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 7
#       5     csv_reader = csv.reader(file)
#       6     for row in csv_reader:
# ----> 7         ranges.append((int(row[0]), int(row[1])))
#       9 print(ranges)
#      11 range_counts = []
#
# IndexError: list index out of range

# %%
import csv  # Make sure to import the csv module if not already imported

# Assuming 'data' is already loaded from somewhere and includes dictionaries with "#Tokens" and "#Method Calls"

file_name = 'input_ranges.csv'
ranges = []

# Read input ranges from the file
with open(file_name, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        ranges.append((int(row[0]), int(row[1])))

print(ranges)

range_counts = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Write output to a CSV file
output_file_path = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/summarized_methods.csv'
with open(output_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 12
#      10     csv_reader = csv.reader(file)
#      11     for row in csv_reader:
# ---> 12         ranges.append((int(row[0]), int(row[1])))
#      14 print(ranges)
#      16 range_counts = []
#
# IndexError: list index out of range

# %%
file_name = 'input_ranges.csv'
ranges = []

# Read input ranges from the file
with open(file_name, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Write output to a CSV file
output_file_path = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/summarized_methods.csv'
with open(output_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Invalid range row: []
# ...

# %%
import csv

# File paths
methods_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
ranges_file = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/input_ranges.csv'
output_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/summarized_methods.csv'

# List to store methods data
methods_data = []

# Read method details from the file
with open(methods_file, mode='r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        try:
            methods_data.append({
                "Index": int(row["Index"]),
                "Method Name": row["Method Name"].strip(),
                "#Tokens": int(row["#Tokens"]),
                "#Method Calls": int(row["#Method Calls"])
            })
        except ValueError as e:
            print(f"Error processing row: {row}")
            print(f"Error message: {e}")
            continue

print("Number of method data rows:", len(methods_data))

# List to store ranges read from the file
ranges = []

# Read token ranges from the file
with open(ranges_file, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Write output to a CSV file
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Number of method data rows: 1309838
# Invalid range row: []
# ...

# %%
import csv

# File paths
methods_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
ranges_file = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/input_ranges.csv'
output_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/summarized_methods.csv'

# List to store methods data
methods_data = []

# Read method details from the file
with open(methods_file, mode='r') as file:
    csv_reader = csv.DictReader(file)
    row_count = 0
    error_count = 0
    for row in csv_reader:
        row_count += 1
        try:
            methods_data.append({
                "Index": int(row["Index"]),
                "Method Name": row["Method Name"].strip(),
                "#Tokens": int(row["#Tokens"]),
                "#Method Calls": int(row["#Method Calls"])
            })
        except ValueError as e:
            error_count += 1
            print(f"Error processing row {row_count}: {row}")
            print(f"Error message: {e}")
            continue

print(f"Total rows read: {row_count}")
print(f"Total rows with errors: {error_count}")
print(f"Total valid method data rows: {len(methods_data)}")

# List to store ranges read from the file
ranges = []

# Read token ranges from the file
with open(ranges_file, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Write output to a CSV file
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Total rows read: 1309838
# Total rows with errors: 0
# Total valid method data rows: 1309838
# Invalid range row: []
# ...

# %%
import csv

# File paths
methods_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
ranges_file = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/input_ranges.csv'
output_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/summarized_methods.csv'

# List to store methods data
methods_data = []

# Read method details from the file
with open(methods_file, mode='r') as file:
    csv_reader = csv.DictReader(file)
    row_count = 0
    error_count = 0
    for row in csv_reader:
        row_count += 1
        try:
            methods_data.append({
                "Index": int(row["Index"]),
                "Method Name": row["Method Name"].strip(),
                "#Tokens": int(row["#Tokens"]),
                "#Method Calls": int(row["#Method Calls"])
            })
        except ValueError as e:
            error_count += 1
            print(f"Error processing row {row_count}: {row}")
            print(f"Error message: {e}")
            continue

print(f"Total rows read: {row_count}")
print(f"Total rows with errors: {error_count}")
print(f"Total valid method data rows: {len(methods_data)}")

# List to store ranges read from the file
ranges = []

# Read token ranges from the file
with open(ranges_file, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Additional check to ensure all methods are counted
total_methods = sum(count for _, _, count, _ in range_counts)
if total_methods != len(methods_data):
    print(f"Discrepancy detected: Expected {len(methods_data)}, but got {total_methods} in the range counts.")

# Write output to a CSV file
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Total rows read: 1309838
# Total rows with errors: 0
# Total valid method data rows: 1309838
# Invalid range row: []
# ...

# %%
import csv

# File paths
methods_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
ranges_file = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/input_ranges.csv'
output_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/summarized_methods.csv'

# List to store methods data
methods_data = []

# Read method details from the file
with open(methods_file, mode='r') as file:
    csv_reader = csv.DictReader(file)
    row_count = 0
    error_count = 0
    for row in csv_reader:
        row_count += 1
        try:
            methods_data.append({
                "Index": int(row["Index"]),
                "Method Name": row["Method Name"].strip(),
                "#Tokens": int(row["#Tokens"]),
                "#Method Calls": int(row["#Method Calls"])
            })
        except ValueError as e:
            error_count += 1
            print(f"Error processing row {row_count}: {row}")
            print(f"Error message: {e}")
            continue

print(f"Total rows read: {row_count}")
print(f"Total rows with errors: {error_count}")
print(f"Total valid method data rows: {len(methods_data)}")

# List to store ranges read from the file
ranges = []

# Read token ranges from the file
with open(ranges_file, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []
missing_methods = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Check for missing methods
all_tokens = [d["#Tokens"] for d in methods_data]
counted_tokens = [d["#Tokens"] for d in methods_data if any(r[0] <= d["#Tokens"] <= r[1] for r in ranges)]

missing_tokens = set(all_tokens) - set(counted_tokens)
for token in missing_tokens:
    for method in methods_data:
        if method["#Tokens"] == token:
            missing_methods.append(method)

if missing_methods:
    print(f"Number of missing methods: {len(missing_methods)}")
    print("Missing methods:")
    for method in missing_methods:
        print(method)

# Write output to a CSV file
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Total rows read: 1309838
# Total rows with errors: 0
# Total valid method data rows: 1309838
# Invalid range row: []
# ...

# %%
import csv

# File paths
methods_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/tokencounting_raw_methods_train.csv'
ranges_file = '/home/user1-selab3/Documents/research-shradha/CODE-SPT-Code/spt-code/sources/backup/input_ranges.csv'
output_file = '/home/user1-selab3/Documents/data_shradha/spt-code-new-data/summarized_methods.csv'

# List to store methods data
methods_data = []

# Read method details from the file
with open(methods_file, mode='r') as file:
    csv_reader = csv.DictReader(file)
    row_count = 0
    error_count = 0
    for row in csv_reader:
        row_count += 1
        try:
            methods_data.append({
                "Index": int(row["Index"]),
                "Method Name": row["Method Name"].strip(),
                "#Tokens": int(row["#Tokens"]),
                "#Method Calls": int(row["#Method Calls"])
            })
        except ValueError as e:
            error_count += 1
            print(f"Error processing row {row_count}: {row}")
            print(f"Error message: {e}")
            continue

print(f"Total rows read: {row_count}")
print(f"Total rows with errors: {error_count}")
print(f"Total valid method data rows: {len(methods_data)}")

# List to store ranges read from the file
ranges = []

# Read token ranges from the file
with open(ranges_file, mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) >= 2:  # Ensure there are at least two columns in the row
            try:
                start = int(row[0])
                end = int(row[1])
                ranges.append((start, end))
            except ValueError as e:
                print(f"Error processing range row: {row}")
                print(f"Error message: {e}")
        else:
            print(f"Invalid range row: {row}")

print("Ranges:", ranges)

range_counts = []
missing_methods = []

# Compute counts and method calls for each range
for r in ranges:
    count = sum(1 for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    method_calls_sum = sum(d["#Method Calls"] for d in methods_data if r[0] <= d["#Tokens"] <= r[1])
    range_counts.append((r[0], r[1], count, method_calls_sum))

# Check for missing methods
all_tokens = [d["#Tokens"] for d in methods_data]
counted_tokens = [d["#Tokens"] for d in methods_data if any(r[0] <= d["#Tokens"] <= r[1] for r in ranges)]

missing_tokens = set(all_tokens) - set(counted_tokens)
for token in missing_tokens:
    for method in methods_data:
        if method["#Tokens"] == token:
            missing_methods.append(method)

if missing_methods:
    print(f"Number of missing methods: {len(missing_methods)}")
    print("Missing methods:")
    for method in missing_methods:
        print(method)

# Additional check to ensure all methods are counted
total_methods = sum(count for _, _, count, _ in range_counts)
if total_methods != len(methods_data):
    print(f"Discrepancy detected: Expected {len(methods_data)}, but got {total_methods} in the range counts.")

# Write output to a CSV file
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Ranges of Tokens BGN", "Ranges of Tokens END", "# Methods", "# Method Calls"])
    for r in range_counts:
        writer.writerow(r)

print("Summarized data has been written to 'summarized_methods.csv'.")
# Out:
# Total rows read: 1309838
# Total rows with errors: 0
# Total valid method data rows: 1309838
# Invalid range row: []
# ...
